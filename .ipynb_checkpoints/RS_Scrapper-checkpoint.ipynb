# %%
import scrapper_functions

# %%
if __name__ == '__main__':
    
    # scrapper_functions.write_csv(['Client ID','Balance'], 'D:/synd_data/customer_data.csv', init = True)
    # scrapper_functions.write_csv(['Transaction ID','Transaction DateTime','Client ID','Bill Number','Amount','Comment'], 'D:/synd_data/loyality_data.csv', init = True)
    
    scrapper_functions.get_user_data(10000)
# Out:
# C:\Users\Sergei Fedotov\Desktop\Netology\Python\rs-web-scrapping\scrapper_functions.py:25: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 25 of the file C:\Users\Sergei Fedotov\Desktop\Netology\Python\rs-web-scrapping\scrapper_functions.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   analyzer_soup = BeautifulSoup(response_data)
# Прочитан и занесен пользователь 10000

# %%
import pandas as pd

dataset = pd.read_csv('D:/synd_data/customer_data.csv')

dataset.sort_values(by=['Client ID']).tail(50)
# Out:
#       Client ID        Balance
# 13903     26135    353,00 руб.
# 13937     26136    564,00 руб.
# 13969     26137    511,00 руб.
# 14002     26138  1 967,50 руб.
# 14030     26139    454,90 руб.
# 14062     26140    146,40 руб.
# 14095     26141  1 053,00 руб.
# 14124     26142    200,00 руб.
# 14152     26143    399,00 руб.
# 14186     26144    720,50 руб.
# 14221     26145  1 584,00 руб.
# 14249     26146     56,40 руб.
# 14281     26147    797,00 руб.
# 14313     26148    133,50 руб.
# 14350     26149    200,00 руб.
# 14381     26150    130,60 руб.
# 14409     26151    128,20 руб.
# 14436     26152    200,00 руб.
# 14466     26153    273,00 руб.
# 14500     26154    348,50 руб.
# 14531     26155  3 635,80 руб.
# 14564     26156    599,40 руб.
# 14596     26157     70,00 руб.
# 14627     26158    322,00 руб.
# 14656     26159    200,00 руб.
# 14683     26160    200,00 руб.
# 14708     26161    200,00 руб.
# 14739     26162    181,60 руб.
# 14771     26163    162,50 руб.
# 14804     26164    346,40 руб.
# 14835     26165    200,00 руб.
# 14867     26166    388,50 руб.
# 14897     26167    109,00 руб.
# 14917     26168    734,00 руб.
# 14946     26169  4 393,00 руб.
# 14969     26170    165,50 руб.
# 14996     26171  2 042,30 руб.
# 15019     26172    200,00 руб.
# 15032     26173    107,30 руб.
# 15040     26174    200,00 руб.
# 12618     26175    170,50 руб.
# 12653     26176    200,00 руб.
# 12703     26177  1 127,70 руб.
# 12750     26178    200,00 руб.
# 12803     26179  1 242,40 руб.
# 12850     26180     46,00 руб.
# 12910     26181    250,70 руб.
# 12961     26182      0,00 руб.
# 13014     26183    129,00 руб.
# 13070     26184    200,00 руб.
